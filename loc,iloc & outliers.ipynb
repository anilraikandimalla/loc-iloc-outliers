# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("cirrhosis.csv")

# %%
df.shape
# Out:
# (418, 20)

# %%
df.isna()
# Out:
#         ID  N_Days  Status   Drug    Age    Sex  Ascites  Hepatomegaly  \
# 0    False   False   False  False  False  False    False         False
# 1    False   False   False  False  False  False    False         False
# 2    False   False   False  False  False  False    False         False
# 3    False   False   False  False  False  False    False         False
# 4    False   False   False  False  False  False    False         False
# ..     ...     ...     ...    ...    ...    ...      ...           ...
# 413  False   False   False   True  False  False     True          True
# 414  False   False   False   True  False  False     True          True
# 415  False   False   False   True  False  False     True          True
# 416  False   False   False   True  False  False     True          True
# 417  False   False   False   True  False  False     True          True
#
#      Spiders  Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# ...

# %%
df.isna().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
df['Tryglicerides'].mean()
# Out:
# 124.70212765957447

# %%
df.select_dtypes(include='number').mean()
# Out:
# ID                 209.500000
# N_Days            1917.782297
# Age              18533.351675
# Bilirubin            3.220813
# Cholesterol        369.510563
# Albumin              3.497440
# Copper              97.648387
# Alk_Phos          1982.655769
# SGOT               122.556346
# Tryglicerides      124.702128
# Platelets          257.024570
# Prothrombin         10.731731
# Stage                3.024272
# dtype: float64

# %%
df.fillna(df.select_dtypes(include='number').mean(), inplace=True)

# %%
#df.select_dtypes(include='object').mode()[0]
df.fillna(df.select_dtypes(include='object').mode().iloc[0], inplace=True)

# %%
df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D  D-penicillamine  24472   F       N            Y
# 414  415    1103      C  D-penicillamine  14245   F       N            Y
# 415  416    1055      C  D-penicillamine  20819   F       N            Y
# 416  417     691      C  D-penicillamine  21185   F       N            Y
# 417  418     976      C  D-penicillamine  19358   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# ...

# %%
#iloc & loc

# %%
#second row
df.iloc[2]
# Out:
# ID                             3
# N_Days                      1012
# Status                         D
# Drug             D-penicillamine
# Age                        25594
# Sex                            M
# Ascites                        N
# Hepatomegaly                   N
# Spiders                        N
# Edema                          S
# Bilirubin                    1.4
# Cholesterol                176.0
# Albumin                     3.48
# Copper                     210.0
# Alk_Phos                   516.0
# SGOT                        96.1
# Tryglicerides               55.0
# Platelets                  151.0
# Prothrombin                 12.0
# Stage                        4.0
# Name: 2, dtype: object

# %%
#if want any column
df.iloc[:,10]
# Out:
# 0      14.5
# 1       1.1
# 2       1.4
# 3       1.8
# 4       3.4
#        ...
# 413     1.2
# 414     0.9
# 415     1.6
# 416     0.8
# 417     0.7
# Name: Bilirubin, Length: 418, dtype: float64

# %%
#iloc can exclude the last slicing value (eg: (2:6) then values returns upto 5 means 2to5.
#iloc only take the integer index(number)

# %%
#if want any information on a row and column
df.iloc[2,10]
# Out:
# 1.4

# %%
#if want any row
df.iloc[2,:]
# Out:
# ID                             3
# N_Days                      1012
# Status                         D
# Drug             D-penicillamine
# Age                        25594
# Sex                            M
# Ascites                        N
# Hepatomegaly                   N
# Spiders                        N
# Edema                          S
# Bilirubin                    1.4
# Cholesterol                176.0
# Albumin                     3.48
# Copper                     210.0
# Alk_Phos                   516.0
# SGOT                        96.1
# Tryglicerides               55.0
# Platelets                  151.0
# Prothrombin                 12.0
# Stage                        4.0
# Name: 2, dtype: object

# %%
# if want random multiple rows with particular column, need to provide list [] in the [].
df.iloc[[414,417],10]
# Out:
# 414    0.9
# 417    0.7
# Name: Bilirubin, dtype: float64

# %%
# if want random multiple rows with full particular columns, need to provide list [] in the [].
df.iloc[[414,417],:]
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 414  415    1103      C  D-penicillamine  14245   F       N            Y
# 417  418     976      C  D-penicillamine  19358   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin     Copper     Alk_Phos  \
# 414       N     N        0.9   369.510563     3.83  97.648387  1982.655769
# 417       N     N        0.7   369.510563     3.29  97.648387  1982.655769
#
#            SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# 414  122.556346     124.702128      180.0         11.2    4.0
# 417  122.556346     124.702128      350.0         10.6    4.0

# %%
# if want multiple rows with full particular columns, need to provide list [] in the [].
df.iloc[414:418, :]
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 414  415    1103      C  D-penicillamine  14245   F       N            Y
# 415  416    1055      C  D-penicillamine  20819   F       N            Y
# 416  417     691      C  D-penicillamine  21185   F       N            Y
# 417  418     976      C  D-penicillamine  19358   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin     Copper     Alk_Phos  \
# 414       N     N        0.9   369.510563     3.83  97.648387  1982.655769
# 415       N     N        1.6   369.510563     3.42  97.648387  1982.655769
# 416       N     N        0.8   369.510563     3.75  97.648387  1982.655769
# 417       N     N        0.7   369.510563     3.29  97.648387  1982.655769
#
#            SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# 414  122.556346     124.702128      180.0         11.2    4.0
# 415  122.556346     124.702128      143.0          9.9    3.0
# ...

# %%
# if want multiple rows with particular columns, need to provide list [] in the [].
df.iloc[414:417,[10,13]]
# Out:
#      Bilirubin     Copper
# 414        0.9  97.648387
# 415        1.6  97.648387
# 416        0.8  97.648387

# %%
# if want multiple rows with multiple columns
df.iloc[414:417,10:13]
# Out:
#      Bilirubin  Cholesterol  Albumin
# 414        0.9   369.510563     3.83
# 415        1.6   369.510563     3.42
# 416        0.8   369.510563     3.75

# %%
# if want multiple random columns with multiple random row.
df.iloc[[414,417],[10,13]]
# Out:
#      Bilirubin     Copper
# 414        0.9  97.648387
# 417        0.7  97.648387

# %%
#loc can include the last slicing value (eg: (2:6) then values returns upto 6 means 2to6.
#loc only take the integer index(Number or string) and label 
#column names must be insert like categorical

# %%
# particular row
df.loc[3]
# Out:
# ID                             4
# N_Days                      1925
# Status                         D
# Drug             D-penicillamine
# Age                        19994
# Sex                            F
# Ascites                        N
# Hepatomegaly                   Y
# Spiders                        Y
# Edema                          S
# Bilirubin                    1.8
# Cholesterol                244.0
# Albumin                     2.54
# Copper                      64.0
# Alk_Phos                  6121.8
# SGOT                       60.63
# Tryglicerides               92.0
# Platelets                  183.0
# Prothrombin                 10.3
# Stage                        4.0
# Name: 3, dtype: object

# %%
# multiple rows
df.loc[[2,3,311,382]]
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 311  312     788      C          Placebo  12109   F       N            N
# 382  383    1022     CL  D-penicillamine  13514   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# 2         N     S        1.4   176.000000     3.48  210.000000   516.000000
# 3         Y     S        1.8   244.000000     2.54   64.000000  6121.800000
# 311       Y     N        6.4   576.000000     3.79  186.000000  2115.000000
# 382       N     S        0.8   369.510563     3.00   97.648387  1982.655769
#
#            SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# 2     96.100000      55.000000      151.0         12.0    4.0
# 3     60.630000      92.000000      183.0         10.3    4.0
# ...

# %%
#if want rows and random column
df.loc[[3,10],['Drug']]
# Out:
#                Drug
# 3   D-penicillamine
# 10          Placebo

# %%
#if want slicing rows and random column
df.loc[3:10,['Drug','Age','Sex','Ascites']]
# Out:
#                Drug    Age Sex Ascites
# 3   D-penicillamine  19994   F       N
# 4           Placebo  13918   F       N
# 5           Placebo  24201   F       N
# 6           Placebo  20284   F       N
# 7           Placebo  19379   F       N
# 8   D-penicillamine  15526   F       N
# 9           Placebo  25772   F       Y
# 10          Placebo  19619   F       N

# %%
#if want random rows and random column
df.loc[[15,27,32,100,120,128],['Drug','Age','Sex','Ascites']]
# Out:
#                 Drug    Age Sex Ascites
# 15           Placebo  14772   F       N
# 27           Placebo  16417   F       Y
# 32           Placebo  18731   F       N
# 100          Placebo  16418   F       N
# 120          Placebo  24803   M       Y
# 128  D-penicillamine  23235   F       N

# %%
df.loc[df['Drug'] == "Placebo"]
# Out:
#       ID  N_Days Status     Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 4      5    1504     CL  Placebo  13918   F       N            Y       Y
# 5      6    2503      D  Placebo  24201   F       N            Y       N
# 6      7    1832      C  Placebo  20284   F       N            Y       N
# 7      8    2466      D  Placebo  19379   F       N            N       N
# 9     10      51      D  Placebo  25772   F       Y            N       Y
# ..   ...     ...    ...      ...    ...  ..     ...          ...     ...
# 304  305    1216      C  Placebo  15730   F       N            Y       Y
# 305  306    1216      C  Placebo  20597   F       N            Y       N
# 306  307    1149      C  Placebo  11167   F       N            N       N
# 308  309     994      C  Placebo  21294   F       N            N       N
# 311  312     788      C  Placebo  12109   F       N            N       Y
#
#     Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df.loc[df['Drug'] == "Placebo",'Age':'Albumin']
# Out:
#        Age Sex Ascites Hepatomegaly Spiders Edema  Bilirubin  Cholesterol  \
# 4    13918   F       N            Y       Y     N        3.4        279.0
# 5    24201   F       N            Y       N     N        0.8        248.0
# 6    20284   F       N            Y       N     N        1.0        322.0
# 7    19379   F       N            N       N     N        0.3        280.0
# 9    25772   F       Y            N       Y     Y       12.6        200.0
# ..     ...  ..     ...          ...     ...   ...        ...          ...
# 304  15730   F       N            Y       Y     N        2.9        426.0
# 305  20597   F       N            Y       N     N        0.6        239.0
# 306  11167   F       N            N       N     N        0.8        273.0
# 308  21294   F       N            N       N     N        0.4        260.0
# 311  12109   F       N            N       Y     N        6.4        576.0
#
#      Albumin
# 4       3.53
# 5       3.98
# 6       4.09
# 7       4.00
# ...

# %%
# outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Variables= ['Bilirubin','Cholesterol','Albumin']
df2[Variables].boxplot()
plt.show()

# %%
sns.boxplot(y= 'Cholesterol', data=df)
plt.show()

# %%
lower_limit= df['Cholesterol'].quantile(0.05)
lower_limit
# Out:
# 200.85

# %%
upper_limit= df['Cholesterol'].quantile(0.95)
upper_limit
# Out:
# 608.8999999999999

# %%
df[df['Cholesterol']<lower_limit]
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 9     10      51      D          Placebo  25772   F       Y            N
# 17    18     131      D  D-penicillamine  19698   F       N            Y
# 26    27      77      D          Placebo  19884   F       Y            Y
# 35    36    3611      C          Placebo  20604   F       N            N
# 67    68    4039      C  D-penicillamine  11912   F       N            N
# 72    73    4190      C          Placebo  14060   F       N            N
# 99   100     552      D          Placebo  18799   M       N            Y
# 102  103     110      D          Placebo  17884   F       Y            Y
# 107  108    2583      D  D-penicillamine  18393   F       N            N
# 108  109    2504      C          Placebo  16094   F       N            N
# 120  121     191      D          Placebo  24803   M       Y            Y
# ...

# %%
df[df['Cholesterol']>upper_limit]
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 25    26    1444      D          Placebo  19002   F       N            Y
# 51    52    2386      D  D-penicillamine  18460   M       N            N
# 62    63     859      D          Placebo  17031   F       N            N
# 68    69    1170      D  D-penicillamine  18021   F       N            Y
# 74    75    1191      D  D-penicillamine  15895   F       Y            Y
# 85    86    1657      D  D-penicillamine  19270   F       N            Y
# 89    90    2689      D  D-penicillamine  12227   M       N            N
# 116  117    1083      D  D-penicillamine  18137   F       N            Y
# 118  119     515      D  D-penicillamine  19817   F       N            N
# 129  130    1413      D          Placebo  16154   F       N            Y
# 147  148    1427      D          Placebo  11273   F       N            Y
# 165  166    2721      C          Placebo  15105   F       N            Y
# ...

# %%
df= df[(df['Cholesterol']>lower_limit) & (df['Cholesterol'] < upper_limit)]

# %%
df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# 5      6    2503      D          Placebo  24201   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D  D-penicillamine  24472   F       N            Y
# 414  415    1103      C  D-penicillamine  14245   F       N            Y
# 415  416    1055      C  D-penicillamine  20819   F       N            Y
# 416  417     691      C  D-penicillamine  21185   F       N            Y
# 417  418     976      C  D-penicillamine  19358   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# ...

# %%
df['Cholesterol'].mean()
# Out:
# 343.72716886424934

# %%
sns.boxplot(y= 'Cholesterol', data=df)
plt.show()

# %%
"""
it is perfectly acceptable to have some outliers remaining after applying the quantile method (or any other outlier removal technique).
having some outliers left in dataset after applying a cleaning method like the quantile approach is normal and sometimes necessary. The key is to assess whether the remaining outliers are valid observations and if they are relevant to our analysis. Always consider the context of our data and the implications of any remaining outliers on our findings.
"""
# Out:
# '\nit is perfectly acceptable to have some outliers remaining after applying the quantile method (or any other outlier removal technique).\nhaving some outliers left in dataset after applying a cleaning method like the quantile approach is normal and sometimes necessary. The key is to assess whether the remaining outliers are valid observations and if they are relevant to our analysis. Always consider the context of our data and the implications of any remaining outliers on our findings.\n'
